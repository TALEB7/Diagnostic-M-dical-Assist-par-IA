# %%
import pandas as pd
data = pd.read_csv('/kaggle/input/medical-data/medical_data.csv')
data.head()
# Out:
#                                      Patient_Problem  \
# 0  Constant fatigue and muscle weakness, struggli...
# 1  Frequent severe migraines, sensitivity to ligh...
# 2  Sudden weight gain and feeling cold, especiall...
# 3  High fever, sore throat, and swollen lymph nod...
# 4  Excessive thirst and frequent urination, dry m...
#
#                     Disease                                       Prescription
# 0  Chronic Fatigue Syndrome  Cognitive behavioral therapy, graded exercise ...
# 1        Migraine with Aura  Prescription triptans, avoid triggers like bri...
# 2            Hypothyroidism  Levothyroxine to regulate thyroid hormone levels.
# 3             Mononucleosis            Rest and hydration, ibuprofen for pain.
# 4         Diabetes Mellitus             Insulin therapy and lifestyle changes.

# %%
data.shape
# Out:
# (407, 3)

# %%
data.Patient_Problem[231]
# Out:
# "I've experienced a loss of appetite and don't enjoy food anymore."

# %%
import pandas as pd
import numpy as np
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.utils import to_categorical
from sklearn.preprocessing import LabelEncoder

data = pd.read_csv('/kaggle/input/medical-data/medical_data.csv')

# Initialising the Tokenizer
tokenizer = Tokenizer(num_words=5000, oov_token="<OOV>")
tokenizer.fit_on_texts(data['Patient_Problem'])

# Converting text to sequences
sequences = tokenizer.texts_to_sequences(data['Patient_Problem'])

# Padding the sequences
max_length = max(len(x) for x in sequences)
padded_sequences = pad_sequences(sequences, maxlen=max_length, padding='post')

# Encoding the labels
label_encoder_disease = LabelEncoder()
label_encoder_prescription = LabelEncoder()

disease_labels = label_encoder_disease.fit_transform(data['Disease'])
prescription_labels = label_encoder_prescription.fit_transform(data['Prescription'])

# Converting labels to categorical
disease_labels_categorical = to_categorical(disease_labels)
prescription_labels_categorical = to_categorical(prescription_labels)

# Combining the labels into a single multi-label target variable
Y = np.hstack((disease_labels_categorical, prescription_labels_categorical))

# %%
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Embedding, LSTM, Dense

# Defining model architecture
input_layer = Input(shape=(max_length,))
embedding = Embedding(input_dim=5000, output_dim=64)(input_layer)
lstm_layer = LSTM(64)(embedding)
disease_output = Dense(len(label_encoder_disease.classes_), activation='softmax', name='disease_output')(lstm_layer)
prescription_output = Dense(len(label_encoder_prescription.classes_), activation='softmax', name='prescription_output')(lstm_layer)

model = Model(inputs=input_layer, outputs=[disease_output, prescription_output])

model.compile(
    loss={'disease_output': 'categorical_crossentropy', 'prescription_output': 'categorical_crossentropy'},
    optimizer='adam',
    metrics={'disease_output': ['accuracy'], 'prescription_output': ['accuracy']}
)

# Model summary
model.summary()

# Training the model
model.fit(padded_sequences, {'disease_output': disease_labels_categorical, 'prescription_output': prescription_labels_categorical},
          epochs=100, batch_size=32)
# Out:
# Model: "functional_5"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_2       │ (None, 17)        │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ embedding_2         │ (None, 17, 64)    │    320,000 │ input_layer_2[0]… │
# │ (Embedding)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lstm_2 (LSTM)       │ (None, 64)        │     33,024 │ embedding_2[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ disease_output      │ (None, 178)       │     11,570 │ lstm_2[0][0]      │
# │ (Dense)             │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ prescription_output │ (None, 388)       │     25,220 │ lstm_2[0][0]      │
# │ (Dense)             │                   │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 389,814 (1.49 MB)
#  Trainable params: 389,814 (1.49 MB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - disease_output_accuracy: 0.0123 - loss: 11.1439 - prescription_output_accuracy: 0.0000e+00
# Epoch 2/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - disease_output_accuracy: 0.0254 - loss: 11.1231 - prescription_output_accuracy: 0.0024
# Epoch 3/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - disease_output_accuracy: 0.0345 - loss: 11.0770 - prescription_output_accuracy: 0.0197
# Epoch 4/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - disease_output_accuracy: 0.0251 - loss: 10.9756 - prescription_output_accuracy: 0.0166
# Epoch 5/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - disease_output_accuracy: 0.0424 - loss: 10.8290 - prescription_output_accuracy: 0.0264
# Epoch 6/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - disease_output_accuracy: 0.0267 - loss: 10.8514 - prescription_output_accuracy: 0.0112
# Epoch 7/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - disease_output_accuracy: 0.0305 - loss: 10.6665 - prescription_output_accuracy: 0.0225
# Epoch 8/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - disease_output_accuracy: 0.0542 - loss: 10.4421 - prescription_output_accuracy: 0.0191
# Epoch 9/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - disease_output_accuracy: 0.0376 - loss: 10.2813 - prescription_output_accuracy: 0.0229
# Epoch 10/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - disease_output_accuracy: 0.0535 - loss: 10.0987 - prescription_output_accuracy: 0.0144
# Epoch 11/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - disease_output_accuracy: 0.0926 - loss: 9.7994 - prescription_output_accuracy: 0.0122
# Epoch 12/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - disease_output_accuracy: 0.1141 - loss: 9.5497 - prescription_output_accuracy: 0.0268
# Epoch 13/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - disease_output_accuracy: 0.0977 - loss: 9.3460 - prescription_output_accuracy: 0.0381
# Epoch 14/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - disease_output_accuracy: 0.1121 - loss: 9.0603 - prescription_output_accuracy: 0.0372
# Epoch 15/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - disease_output_accuracy: 0.1711 - loss: 8.7602 - prescription_output_accuracy: 0.0540
# Epoch 16/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - disease_output_accuracy: 0.1887 - loss: 8.5404 - prescription_output_accuracy: 0.0720
# Epoch 17/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - disease_output_accuracy: 0.1736 - loss: 8.3953 - prescription_output_accuracy: 0.0526
# Epoch 18/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - disease_output_accuracy: 0.1776 - loss: 8.2468 - prescription_output_accuracy: 0.0597
# Epoch 19/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - disease_output_accuracy: 0.2052 - loss: 8.0027 - prescription_output_accuracy: 0.0732
# Epoch 20/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - disease_output_accuracy: 0.2215 - loss: 7.8311 - prescription_output_accuracy: 0.0816
# Epoch 21/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - disease_output_accuracy: 0.2313 - loss: 7.6845 - prescription_output_accuracy: 0.0906
# Epoch 22/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - disease_output_accuracy: 0.2449 - loss: 7.4664 - prescription_output_accuracy: 0.1034
# Epoch 23/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - disease_output_accuracy: 0.2126 - loss: 7.5166 - prescription_output_accuracy: 0.0909
# Epoch 24/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - disease_output_accuracy: 0.2762 - loss: 7.3093 - prescription_output_accuracy: 0.0841
# Epoch 25/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - disease_output_accuracy: 0.2884 - loss: 7.1138 - prescription_output_accuracy: 0.0927
# Epoch 26/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - disease_output_accuracy: 0.3068 - loss: 6.9206 - prescription_output_accuracy: 0.1411
# Epoch 27/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - disease_output_accuracy: 0.2787 - loss: 6.7912 - prescription_output_accuracy: 0.1670
# Epoch 28/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - disease_output_accuracy: 0.2996 - loss: 6.7307 - prescription_output_accuracy: 0.1654
# Epoch 29/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - disease_output_accuracy: 0.2859 - loss: 6.7291 - prescription_output_accuracy: 0.1626
# Epoch 30/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - disease_output_accuracy: 0.3507 - loss: 6.5121 - prescription_output_accuracy: 0.1696
# Epoch 31/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - disease_output_accuracy: 0.3245 - loss: 6.4283 - prescription_output_accuracy: 0.1882
# Epoch 32/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - disease_output_accuracy: 0.3414 - loss: 6.3421 - prescription_output_accuracy: 0.1668
# Epoch 33/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - disease_output_accuracy: 0.3550 - loss: 6.2179 - prescription_output_accuracy: 0.2078
# Epoch 34/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - disease_output_accuracy: 0.3056 - loss: 6.1774 - prescription_output_accuracy: 0.2206
# Epoch 35/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - disease_output_accuracy: 0.3722 - loss: 6.0305 - prescription_output_accuracy: 0.1958
# Epoch 36/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - disease_output_accuracy: 0.3841 - loss: 5.9487 - prescription_output_accuracy: 0.2727
# Epoch 37/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - disease_output_accuracy: 0.3564 - loss: 5.9028 - prescription_output_accuracy: 0.2080
# Epoch 38/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - disease_output_accuracy: 0.3920 - loss: 5.8048 - prescription_output_accuracy: 0.2508
# Epoch 39/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - disease_output_accuracy: 0.4388 - loss: 5.6666 - prescription_output_accuracy: 0.2629
# Epoch 40/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - disease_output_accuracy: 0.4513 - loss: 5.6129 - prescription_output_accuracy: 0.2420
# Epoch 41/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - disease_output_accuracy: 0.4537 - loss: 5.4634 - prescription_output_accuracy: 0.3327
# Epoch 42/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - disease_output_accuracy: 0.4534 - loss: 5.3892 - prescription_output_accuracy: 0.3347
# Epoch 43/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - disease_output_accuracy: 0.4891 - loss: 5.3109 - prescription_output_accuracy: 0.3092
# Epoch 44/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - disease_output_accuracy: 0.4958 - loss: 5.2428 - prescription_output_accuracy: 0.3218
# Epoch 45/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - disease_output_accuracy: 0.5353 - loss: 5.1016 - prescription_output_accuracy: 0.3481
# Epoch 46/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - disease_output_accuracy: 0.5160 - loss: 5.1539 - prescription_output_accuracy: 0.3464
# Epoch 47/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - disease_output_accuracy: 0.5383 - loss: 4.9749 - prescription_output_accuracy: 0.3680
# Epoch 48/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - disease_output_accuracy: 0.5481 - loss: 4.9361 - prescription_output_accuracy: 0.3342
# Epoch 49/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - disease_output_accuracy: 0.5028 - loss: 4.9858 - prescription_output_accuracy: 0.3665
# Epoch 50/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - disease_output_accuracy: 0.5277 - loss: 4.9130 - prescription_output_accuracy: 0.3406
# Epoch 51/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - disease_output_accuracy: 0.5354 - loss: 4.7589 - prescription_output_accuracy: 0.3774
# Epoch 52/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - disease_output_accuracy: 0.5687 - loss: 4.7394 - prescription_output_accuracy: 0.3591
# Epoch 53/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - disease_output_accuracy: 0.5097 - loss: 4.7098 - prescription_output_accuracy: 0.4244
# Epoch 54/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - disease_output_accuracy: 0.6132 - loss: 4.4939 - prescription_output_accuracy: 0.4289
# Epoch 55/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - disease_output_accuracy: 0.5544 - loss: 4.5846 - prescription_output_accuracy: 0.4128
# Epoch 56/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - disease_output_accuracy: 0.5765 - loss: 4.4869 - prescription_output_accuracy: 0.4462
# Epoch 57/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - disease_output_accuracy: 0.5561 - loss: 4.4146 - prescription_output_accuracy: 0.4587
# Epoch 58/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - disease_output_accuracy: 0.6115 - loss: 4.2265 - prescription_output_accuracy: 0.4512
# Epoch 59/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - disease_output_accuracy: 0.6269 - loss: 4.2037 - prescription_output_accuracy: 0.4583
# Epoch 60/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - disease_output_accuracy: 0.6741 - loss: 4.1121 - prescription_output_accuracy: 0.5557
# Epoch 61/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - disease_output_accuracy: 0.6470 - loss: 4.0950 - prescription_output_accuracy: 0.5378
# Epoch 62/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - disease_output_accuracy: 0.6389 - loss: 4.1155 - prescription_output_accuracy: 0.5202
# Epoch 63/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - disease_output_accuracy: 0.6314 - loss: 4.1664 - prescription_output_accuracy: 0.4903
# Epoch 64/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - disease_output_accuracy: 0.6420 - loss: 4.0794 - prescription_output_accuracy: 0.4890
# Epoch 65/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - disease_output_accuracy: 0.6594 - loss: 3.9902 - prescription_output_accuracy: 0.5121
# Epoch 66/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - disease_output_accuracy: 0.6575 - loss: 4.0940 - prescription_output_accuracy: 0.4625
# Epoch 67/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - disease_output_accuracy: 0.6740 - loss: 4.0143 - prescription_output_accuracy: 0.4586
# Epoch 68/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - disease_output_accuracy: 0.6604 - loss: 3.9574 - prescription_output_accuracy: 0.4957
# Epoch 69/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - disease_output_accuracy: 0.6439 - loss: 3.8749 - prescription_output_accuracy: 0.4798
# Epoch 70/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - disease_output_accuracy: 0.6724 - loss: 3.9991 - prescription_output_accuracy: 0.4918
# Epoch 71/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - disease_output_accuracy: 0.6943 - loss: 3.7858 - prescription_output_accuracy: 0.5019
# Epoch 72/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - disease_output_accuracy: 0.6761 - loss: 3.7886 - prescription_output_accuracy: 0.4941
# Epoch 73/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - disease_output_accuracy: 0.7378 - loss: 3.6181 - prescription_output_accuracy: 0.5501
# Epoch 74/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - disease_output_accuracy: 0.7057 - loss: 3.6128 - prescription_output_accuracy: 0.5690
# Epoch 75/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - disease_output_accuracy: 0.7381 - loss: 3.6384 - prescription_output_accuracy: 0.5245
# Epoch 76/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - disease_output_accuracy: 0.7348 - loss: 3.5589 - prescription_output_accuracy: 0.5557
# Epoch 77/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - disease_output_accuracy: 0.7153 - loss: 3.5262 - prescription_output_accuracy: 0.5528
# Epoch 78/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - disease_output_accuracy: 0.7754 - loss: 3.4020 - prescription_output_accuracy: 0.5739
# Epoch 79/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - disease_output_accuracy: 0.7240 - loss: 3.4510 - prescription_output_accuracy: 0.5771
# Epoch 80/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - disease_output_accuracy: 0.7697 - loss: 3.3576 - prescription_output_accuracy: 0.5602
# Epoch 81/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - disease_output_accuracy: 0.7852 - loss: 3.2351 - prescription_output_accuracy: 0.6046
# Epoch 82/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - disease_output_accuracy: 0.7796 - loss: 3.2207 - prescription_output_accuracy: 0.6115
# Epoch 83/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - disease_output_accuracy: 0.7756 - loss: 3.2260 - prescription_output_accuracy: 0.6162
# Epoch 84/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - disease_output_accuracy: 0.7976 - loss: 3.1081 - prescription_output_accuracy: 0.6259
# Epoch 85/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - disease_output_accuracy: 0.7446 - loss: 3.1814 - prescription_output_accuracy: 0.5897
# Epoch 86/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - disease_output_accuracy: 0.7943 - loss: 3.1652 - prescription_output_accuracy: 0.6548
# Epoch 87/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - disease_output_accuracy: 0.7717 - loss: 3.1762 - prescription_output_accuracy: 0.5738
# Epoch 88/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - disease_output_accuracy: 0.8005 - loss: 3.0623 - prescription_output_accuracy: 0.5930
# Epoch 89/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - disease_output_accuracy: 0.8160 - loss: 2.9624 - prescription_output_accuracy: 0.6237
# Epoch 90/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - disease_output_accuracy: 0.8286 - loss: 2.9399 - prescription_output_accuracy: 0.6185
# Epoch 91/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - disease_output_accuracy: 0.8189 - loss: 2.9783 - prescription_output_accuracy: 0.6152
# Epoch 92/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - disease_output_accuracy: 0.8176 - loss: 2.9669 - prescription_output_accuracy: 0.6204
# Epoch 93/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - disease_output_accuracy: 0.8100 - loss: 2.9223 - prescription_output_accuracy: 0.6398
# Epoch 94/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - disease_output_accuracy: 0.8151 - loss: 2.7811 - prescription_output_accuracy: 0.6737
# Epoch 95/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - disease_output_accuracy: 0.8500 - loss: 2.7165 - prescription_output_accuracy: 0.6494
# Epoch 96/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - disease_output_accuracy: 0.8189 - loss: 2.8227 - prescription_output_accuracy: 0.6038
# Epoch 97/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - disease_output_accuracy: 0.8407 - loss: 2.7800 - prescription_output_accuracy: 0.6287
# Epoch 98/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - disease_output_accuracy: 0.8151 - loss: 2.7223 - prescription_output_accuracy: 0.6672
# Epoch 99/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - disease_output_accuracy: 0.8634 - loss: 2.6021 - prescription_output_accuracy: 0.6599
# Epoch 100/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - disease_output_accuracy: 0.8714 - loss: 2.6303 - prescription_output_accuracy: 0.7014

# %%
def make_prediction(patient_problem):
    # Preprocessing the input
    sequence = tokenizer.texts_to_sequences([patient_problem])
    padded_sequence = pad_sequences(sequence, maxlen=max_length, padding='post')
    
    # Making prediction
    prediction = model.predict(padded_sequence)
    
    # Decoding the prediction
    disease_index = np.argmax(prediction[0], axis=1)[0]
    prescription_index = np.argmax(prediction[1], axis=1)[0]
    
    disease_predicted = label_encoder_disease.inverse_transform([disease_index])[0]
    prescription_predicted = label_encoder_prescription.inverse_transform([prescription_index])[0]
    
    print(f"Predicted Disease: {disease_predicted}")
    print(f"Suggested Prescription: {prescription_predicted}")


patient_input = "I've experienced a loss of appetite and don't enjoy food anymore."
make_prediction(patient_input)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step
# Predicted Disease: Depression
# Suggested Prescription: Antidepressants; eating nutrient-rich foods.

# %%
model.save('/kaggle/working/model.h5')
